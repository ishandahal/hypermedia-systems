# %%
from dialoghelper import *

# %%
tool_info()

# %% [markdown]
# Tools available from `dialoghelper`:
#
# - &`curr_dialog`: Get the current dialog info.
# - &`msg_idx`: Get absolute index of message in dialog.
# - &`add_html`: Send HTML to the browser to be swapped into the DOM using hx-swap-oob.
# - &`find_msg_id`: Get the current message id.
# - &`find_msgs`: Find messages in current specific dialog that contain the given information.
#   - (solveit can often get this id directly from its context, and will not need to use this if the required information is already available to it.)
# - &`read_msg`: Get the message indexed in the current dialog.
#   - To get the exact message use `n=0` and `relative=True` together with `msgid`.
#   - To get a relative message use `n` (relative position index).
#   - To get the nth message use `n` with `relative=False`, e.g `n=0` first message, `n=-1` last message.
# - &`del_msg`: Delete a message from the dialog.
# - &`add_msg`: Add/update a message to the queue to show after code execution completes.
# - &`update_msg`: Update an existing message.
# - &`url2note`: Read URL as markdown, and add a note below current message with the result
# - &`msg_insert_line`: Insert text at a specific location in a message.
# - &`msg_str_replace`: Find and replace text in a message.
# - &`msg_strs_replace`: Find and replace multiple strings in a message.
# - &`msg_replace_lines`: Replace a range of lines in a message with new content.
#   - Always first use `read_msg( msgid=msgid, n=0, relative=True, nums=True)` to view the content with line numbers.

# %%
content_url = "https://hypermedia.systems/introduction/"
content = url2note(content_url)

# %% [markdown]
# [Previous: Hypermedia Concepts](/part/hypermedia-concepts/)
#
# [Next: Hypermedia: A Reintroduction](/hypermedia-a-reintroduction/)

# %% [markdown]
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Here's a summary for continuing the learning journey:
#
# ---
#
# **Learner Context**: New to web programming, comfortable with Python (not expert level), prefers learning through code and interactive exploration.
#
# **Chapter Covered**: Foreword of "Hypermedia Systems" by Gross, Stepinski, and Akşimşek
#
# **Key Concepts Discussed**:
#
# 1. **Hypermedia vs Regular Media**: Regular media is static (books, photos). Hypermedia is linked and interactive — content that connects to other content and responds to actions (clickable links, buttons).
#
# 2. **REST (REpresentational State Transfer)**: Guidelines for how computers talk over the web. Used restaurant analogy:
#    - *Without REST*: Waiter remembers your history, no menu, fragile, doesn't scale
#    - *With REST*: Fresh menu each visit, stateless, any waiter can serve you, self-contained interactions
#
# 3. **Evolution of Web Development**:
#    - Early web: Click → full page reload → server sends complete HTML with links (hypermedia approach)
#    - SPAs (2010s+): Single page loads, JavaScript fetches JSON data, rebuilds page parts — faster feel but more complex
#
# 4. **SPAs vs Hypermedia**:
#    - SPAs: Good for rich interactive apps (Figma, Google Docs), offline support, complex state
#    - Hypermedia: Good for content-driven sites, simpler code, easier maintenance
#    - HTMX: Middle ground — hypermedia with SPA-like smoothness where needed
#
# 5. **Book's Thesis**: Hypermedia was a great idea that got overlooked. Most apps don't need SPA complexity. Start simple, add complexity only when needed.
#
# ---
#
# Ready for the next chapter: *Introduction*

# %% [markdown]
# # Introduction
#
# Contents
#
#   * [What is a Hypermedia System?](/introduction/#what-is-a-hypermedia-system)
#   * [Hypermedia-Driven Applications](/introduction/#hypermedia-driven-applications)
#   * [Goals](/introduction/#goals)
#   * [Book Layout](/introduction/#book-layout)
#   * [Hypermedia: A New Generation](/introduction/#hypermedia--a-new-generation)
#   * [HTML Notes: Hypermedia In Practice](/introduction/#html-note-title)
#
#
#
# This is a book about building applications using hypermedia systems. _Hypermedia systems_ might seem like a strange phrase: how is hypermedia a _system_? Isn’t hypermedia just a way to link documents together?
#
# Like with HTML, on the World Wide Web?
#
# What do you mean hypermedia _systems_?
#
# Well, yes, HTML is _a_ hypermedia. But there is more to the way the web works than just HTML: HTTP, the Hyper Text Transfer Protocol, is what transfers HTML from servers to clients, and there are many details and features associated with it: caching, various headers, response codes, and so forth.
#
# And then, of course, there are _hypermedia servers_ , which present _hypermedia APIs_ (yes, _APIs_) to clients over the network.
#
# And, finally, there is the all-important _hypermedia client_ : a software client that understands how to render a _hypermedia response_ intelligibly to a human, so that a human can interact with the remote system. The most widely known and used hypermedia clients are, of course, web browsers.
#
# Web browsers are perhaps the most sophisticated pieces of software we use. They not only understand HTML, CSS and many other file formats, but they also provide a JavaScript runtime and programming environment that is so powerful that web developers can create entire applications in it that are nearly as sophisticated as _thick clients_ , that is, native applications.
#
# This JavaScript runtime is so powerful, in fact, that today many developers ignore the _hypermedia_ features of the browser, in favor of building their web applications entirely in JavaScript. Applications built in this manner have come to be called Single Page Applications (SPAs). Rather than navigating between pages, these web applications use JavaScript for updating the user interface directly. When they communicate with a server, these applications typically use JSON API calls via AJAX. And they often update the user interface using a “reactive” style frontend JavaScript library.
#
# In these applications HTML becomes a (somewhat awkward) graphical interface description language that is used because, for historical reasons, that’s what happens to be there, in the browser.
#
# Applications built in this style are not _hypermedia-driven_ : they do not take advantage of the underlying hypermedia system of the web.
#
# To explain what a hypermedia-driven application looks like, and to contrast it with the popular SPA approach of today, we need to first explore the entire _hypermedia system_ of the web, beyond just discussing HTML. We need to look at the _network architecture_ of the web, including how a web server delivers a hypermedia API, and how to effectively use the hypermedia features available in the hypermedia _client_ (e.g., the browser).
#
# Each of these are important aspects of building an effective hypermedia-driven application, and it is the entire _hypermedia system_ that comes together to make hypermedia such a powerful architecture.

# %% [markdown]
# As you are already aware of it, I am relatively new to web programming. I think I have a decent grasp. Are there any points that are worth digging into?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Great question! You've covered some solid ground. Looking at this Introduction, a few concepts stand out that might be worth exploring deeper:
#
# 1. **"Hypermedia APIs"** — The chapter mentions that servers present "hypermedia APIs" to clients. This is interesting because most people think of APIs as JSON endpoints. How is a hypermedia API different?
#
# 2. **The browser as a "hypermedia client"** — It's described as perhaps the most sophisticated software we use. What makes it so special as a *hypermedia* client specifically?
#
# 3. **Why SPAs "ignore the hypermedia features"** — What exactly are they ignoring, and what's the trade-off?
#
# 4. **"Network architecture of the web"** — This hints at how HTTP, caching, headers, and response codes all fit together as part of the system.
#
# Which of these catches your curiosity? Or is there something else from the chapter you'd like to dig into?

# %% [markdown]
# Can we talk about hypermedia APIs
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Absolutely! This is a really interesting concept that often surprises people.
#
# When most developers hear "API," they think of something like:
#
# ```
# GET /users/123  →  { "id": 123, "name": "Alice", "email": "alice@example.com" }
# ```
#
# That's a **data API** — the server sends back raw data (usually JSON), and the *client* has to know what to do with it. The client needs to be pre-programmed with knowledge of all the endpoints, what data they return, and how to display it.
#
# A **hypermedia API** is different. Instead of sending just data, the server sends back *content that includes its own controls* — links and forms that tell the client what actions are possible *right now*.
#
# Think about when you visit a webpage: you don't need to know in advance what URLs exist on that site. The page itself shows you links you can click. The *server* is telling you your options through the hypermedia it sends.
#
# Here's the key insight: **with a hypermedia API, the server stays in control of what the client can do**, because it sends the available actions along with the content.
#
# Does that distinction make sense so far? Any questions before we look at what this means in practice?

# %% [markdown]
# Sort of. Can you give concrete example of hypermedia api contrasted to illustrate the difference
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Sure! Let's say you're building a simple shopping cart.
#
# **Data API approach (JSON):**
#
# ```
# GET /cart/456
#
# Response:
# {
#   "id": 456,
#   "items": [{"name": "Book", "price": 20}],
#   "total": 20
# }
# ```
#
# The client receives raw data. To do anything with it — like add an item or checkout — the client must *already know* the URLs and methods to call (e.g., `POST /cart/456/items`, `POST /cart/456/checkout`). That knowledge is baked into the client code.
#
# **Hypermedia API approach (HTML):**
#
# ```html
# GET /cart/456
#
# Response:
# <div class="cart">
#   <p>Book - $20</p>
#   <p>Total: $20</p>
#
#   <form action="/cart/456/items" method="POST">
#     <input name="product_id">
#     <button>Add Item</button>
#   </form>
#
#   <a href="/checkout/456">Proceed to Checkout</a>
# </div>
# ```
#
# See the difference? The response *itself* contains the controls — the form to add items, the link to checkout. The client (browser) doesn't need to know those URLs in advance. It just renders what the server sends and lets the user interact with it.
#
# If the cart were empty, the server might not include the checkout link at all. The server controls what's possible at each moment.
#
# Does that make the distinction clearer?

# %% [markdown]
# Looks like API is a more general term. Is it just an agreement between two paries?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Yes, exactly! You've hit on the core idea.
#
# **API** stands for **Application Programming Interface**. At its heart, it's just a contract — an agreement about how two pieces of software will communicate with each other.
#
# It could be:
# - A web server and a browser (like we've been discussing)
# - Two programs on the same computer
# - A library and the code that uses it
# - An operating system and applications running on it
#
# For example, when you write `len([1, 2, 3])` in Python, you're using Python's API for lists. The "contract" is: *give me a list, I'll return its length*.
#
# So when we say "hypermedia API" vs "data API," we're really talking about *what kind of contract* the server and client have:
# - **Data API**: "I'll send you raw data; you figure out what to do with it"
# - **Hypermedia API**: "I'll send you content with built-in controls; just render it and let users interact"
#
# Does that fit with your intuition? And do you see how this changes where the "smarts" live — in the client or the server?

# %% [markdown]
# Yes it does. Thanks. Lets move on to Browser as hypermedia client
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Great, let's explore that!
#
# The chapter describes browsers as "perhaps the most sophisticated pieces of software we use." That's a big claim! But when you think about what a browser actually does as a *hypermedia client*, it's pretty remarkable.
#
# A hypermedia client needs to:
#
# 1. **Fetch** hypermedia from a server (using HTTP)
# 2. **Render** it in a way humans can understand (displaying HTML, CSS, images, etc.)
# 3. **Let users interact** with the controls embedded in that hypermedia (clicking links, submitting forms)
# 4. **Handle the response** and start the cycle again
#
# The browser does all of this *without knowing anything specific about your application*. You can visit any website in the world — one the browser has never seen before — and it just works. The browser doesn't need an update when a new website launches.
#
# Compare that to a native app: if Twitter changes their API, the Twitter app needs an update. But if Twitter changes their website, your browser handles it automatically.
#
# What do you think makes that possible? What does the browser "know" that lets it work with any website?

# %% [markdown]
# The webpage creater knows "something" and the browser also knows that "something" of there is an implicit understanding? For example: browser know how to render html and webpage creater know how to write renderable html. I could be way off here
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# You're not way off at all — you've nailed it!
#
# That shared "something" is the **hypermedia standards**: HTML, HTTP, CSS, and how they work together.
#
# - The **browser** knows how to: parse HTML, render elements, follow links when clicked, submit forms, handle HTTP responses, apply CSS styling, etc.
#
# - The **web developer** knows: if I write a `<a href="...">`, the browser will make it clickable. If I write a `<form>`, the browser will collect the inputs and send them to the server.
#
# Neither side needs to know anything about the *specific application*. They just both understand the same "language" — the hypermedia standards.
#
# This is why the chapter talks about a hypermedia *system*: it's not just HTML alone. It's HTML + HTTP + the browser's behavior + servers that speak HTTP — all working together because everyone agreed on the same standards.
#
# That's the "contract" that makes the whole web work. A webpage from 1995 still renders in a 2025 browser because that contract has been maintained.
#
# Does that click? And do you see how this is different from, say, a mobile app that needs a specific JSON API?

# %% [markdown]
# I think so. The mobile app (assuming it doesn't use hypermedia) might use some other framework to get the data and render the output to its user. And by its nature it is not universal so relies on internal bespoke implementation. Is that right
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Exactly right!
#
# A typical mobile app:
# - Has its own custom code to call specific API endpoints
# - Knows in advance what data to expect (e.g., "the `/users` endpoint returns JSON with these fields")
# - Has its own rendering logic built in ("when I get user data, display it in this specific way")
#
# If the server changes — new field, renamed endpoint, different data structure — the app breaks until developers release an update.
#
# The browser, by contrast, is a **generic hypermedia client**. It doesn't know anything about *your* app. It just knows: "if I see an `<a>` tag, make it clickable; if I see a `<form>`, let the user fill it in and submit it." The *server* controls what appears and what actions are available, sent fresh with each response.
#
# So you've identified the key trade-off:
# - **Bespoke clients** (native apps, SPAs): More control over the experience, but tightly coupled to the server. Changes require coordinated updates.
# - **Hypermedia clients** (browsers): Looser coupling, server stays in control, but you're working within what hypermedia can express.
#
# You're building a solid mental model here! Ready to move on to the next topic — why SPAs "ignore the hypermedia features"? Or would you like to dig deeper into anything first?

# %% [markdown]
# Yes lets continue
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Alright! So why do SPAs "ignore the hypermedia features" of the browser?
#
# Remember what makes the browser special as a hypermedia client: it fetches HTML, renders it, and lets users interact with embedded links and forms. The *server* controls what's possible through the hypermedia it sends.
#
# In a typical SPA:
#
# 1. The browser loads **one HTML page** (often nearly empty — just a `<div id="app">`)
# 2. A big JavaScript bundle takes over
# 3. When the user does something, JavaScript makes an **AJAX call** that returns **JSON** (raw data, not hypermedia)
# 4. JavaScript then **manually updates the page** based on that data
#
# So the browser's hypermedia superpowers — following links, submitting forms, rendering server responses — sit mostly unused. The JavaScript code is doing all that work instead, essentially building a bespoke client *inside* the browser.
#
# The browser becomes just a runtime environment for JavaScript, rather than a hypermedia client.
#
# Does that make sense? Can you see how this brings back the "bespoke client" problem we just discussed — where the client needs to know the API in advance?

# %% [markdown]
# Yes that makes sense. I guess the javascript take over is what lead to react, vue and other framewarks for web development? Can we talk a bit more about what AJAX is
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Yes, you've got it! Once JavaScript started taking over page rendering and state management, things got complex fast. Frameworks like React, Vue, and Angular emerged to help manage that complexity — they provide structured ways to handle data, update the UI, and keep everything in sync.
#
# Now, about **AJAX**...
#
# AJAX stands for **Asynchronous JavaScript and XML** (though these days it's usually JSON, not XML — the name stuck).
#
# Before AJAX, web interactions worked like this:
# 1. User clicks a link or submits a form
# 2. Browser sends request to server
# 3. **Whole page reloads** with the server's response
#
# AJAX changed that. It lets JavaScript make requests to the server **in the background**, without reloading the page. When the response comes back, JavaScript can update just *part* of the page.
#
# The "asynchronous" part means the page doesn't freeze while waiting — the user can keep doing things.
#
# This was genuinely revolutionary when it appeared! It made web apps feel much snappier. The classic example people cite is Google Maps — dragging the map loaded new tiles seamlessly, no page reloads.
#
# But here's the connection to our earlier discussion: AJAX requests typically return **data** (JSON), not **hypermedia** (HTML). So the client has to know what to do with that data.
#
# Does that clarify what AJAX is? Any questions about how it fits into the picture?

# %% [markdown]
# It makes sense though I guess it could be called AJ now rigth? lol. Let's continue to the final point
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Ha! You're right — AJAJ doesn't quite roll off the tongue though! 😄
#
# Okay, the final point: **"Network architecture of the web"** — how HTTP, caching, headers, and response codes all fit together.
#
# The chapter mentions that there's more to the web than just HTML. HTTP (HyperText Transfer Protocol) is the "how" of moving hypermedia around, and it has a lot of features built in:
#
# - **Response codes**: The server tells the client what happened — `200 OK`, `404 Not Found`, `301 Moved Permanently`, etc. The browser knows how to handle these automatically.
#
# - **Headers**: Metadata sent with requests and responses — things like content type, authentication, cookies, and...
#
# - **Caching**: The server can say "this response is good for 24 hours, don't ask again." The browser (or intermediate servers) can store and reuse it.
#
# Here's the key insight: **these are all part of the hypermedia system**. The browser understands them out of the box. When a server sends a `301 redirect`, the browser follows it automatically. When it says "cache this," the browser does.
#
# But in a JavaScript-heavy SPA making JSON API calls? The JavaScript code often has to handle all this manually.
#
# What aspects of this would you like to explore more — response codes, caching, headers? Or does the overall picture feel complete?

# %% [markdown]
# This is good. I will keep reading now. Thanks
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# You're very welcome! You've built a solid understanding of these concepts — hypermedia APIs, the browser as a hypermedia client, and how it all fits together as a system.
#
# Enjoy the rest of the reading! Feel free to come back anytime you want to discuss more or dig into something that comes up. Happy learning! 📚

# %% [markdown]
# ## What is a Hypermedia System?
#
# To understand what a hypermedia system is we’ll first take an in-depth look at _the_ canonical hypermedia system: the World Wide Web. Roy Fielding, an engineer who helped create specifications and build the implementations of many early pieces of the web, gave us the term REpresentational State Transfer, or REST. In his PhD dissertation he described REST as a _network architecture_ , and he contrasted it with earlier approaches to building distributed software.
#
# We define a _hypermedia system_ as a system that adheres to the RESTful network architecture in Fielding’s _original_ sense of this term.
#
# Unfortunately, today, you probably associate the term “REST” with JSON APIs, since that is where the term is typically used in industry. This is a misapplied use of the term REST because JSON is not a _natural_ hypermedia due to the absence of hypermedia controls. The exchange of hypermedia is an explicit requirement for a system to be considered “RESTful.” It is a long story how we got here, using the term REST so incorrectly, and we will go into the details later in this book. But, for now, if you think REST implies JSON, please try to set that understanding aside while reading this book, and come to the concept with fresh eyes.
#
# It is important to understand that, in his dissertation, Fielding was describing The World Wide Web as it existed in the late 1990s. The web, at that point, was simply web browsers exchanging hypermedia. That system, with its simple links and forms, was what Fielding was calling RESTful.
#
# JSON APIs were a decade away from becoming a common tool in web development: REST was about _hypermedia_ and the 1.0 version of the web.

# %% [markdown]
# Can you help me make sense of of the distinction between REST for JSON APIs, like it's used now and the way it's meant to be used as the author says. I know the details will be coming up in the future as the author  but I would like to get an understanding of it. So if you could help me understand it in a simple way, it would be great.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Absolutely! This connects nicely to what we discussed earlier about hypermedia APIs vs data APIs.
#
# **REST as Fielding meant it (late 1990s web):**
#
# When you visited a webpage, the server sent HTML containing links and forms. Your browser rendered it, you clicked a link, the server sent *another* HTML page with *new* links and forms. The server guided you through the application by sending hypermedia — content with embedded controls.
#
# The key: each response told you what you could do next. The client (browser) didn't need special knowledge.
#
# **"REST" as commonly used today:**
#
# ```
# GET /api/users/123  →  { "id": 123, "name": "Alice" }
# ```
#
# This is just data. No links, no forms, no controls. The client must *already know* all the endpoints and what to do with the data. The JSON itself doesn't tell you what actions are possible.
#
# **The mismatch:**
#
# People started calling any HTTP API "RESTful" — especially if it used nice URLs and HTTP methods like GET, POST, PUT, DELETE. But that misses Fielding's core point: REST requires **hypermedia** — responses that include their own controls.
#
# JSON *can* include links (there are formats like HAL and JSON-API that try this), but it doesn't naturally, and most JSON APIs don't bother.
#
# Does that help clarify the distinction?

# %% [markdown]
# I think I understand. Please let me know if my understanding is correct. So the way it's currently used, the JSON, which is called the "restful" is simply restful in a way that each API calls don't have to remember anything. So there is no state stored. However, the way fielding imagined would be the restful aspect of it being the entire content of transfer between server and the client which in this case is the browser Correct? So there is some aspect of restfulness in a sense that there is no state awareness in current way it is used but it's not how Fielding imagined it originally, is that correct?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Yes, you've got it! That's a really thoughtful breakdown.
#
# You're right that **statelessness** is one aspect of REST that modern JSON APIs often do follow — each request contains everything the server needs, no session memory required.
#
# But Fielding's REST had *multiple* constraints, and statelessness was just one of them. The one that gets ignored most is **hypermedia as the engine of application state** (sometimes called HATEOAS — a mouthful!).
#
# This means: the *hypermedia itself* should tell the client what state transitions (actions) are possible. Not documentation. Not prior knowledge baked into the client. The response itself.
#
# So your summary is spot on:
# - **Current "REST"**: Stateless? ✓ Often yes. Hypermedia-driven? ✗ Usually no.
# - **Fielding's REST**: Stateless? ✓ Yes. Hypermedia-driven? ✓ Yes — this was central.
#
# The industry grabbed the term "REST," kept the parts that were convenient (statelessness, nice URLs, HTTP methods), and quietly dropped the hypermedia requirement — which was actually the heart of it.
#
# Does that confirm and extend your understanding?

# %% [markdown]
# Yes it does. Thanks. I will continue reading and come back when I need help
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Perfect! You're building a really solid understanding of these concepts. Enjoy your reading, and I'm here whenever you want to discuss more. Happy learning! 📖

# %% [markdown]
# ## Hypermedia-Driven Applications
#
# In this book we are going to take a look at hypermedia as a _system architecture_ and then explore some practical, _modern_ approaches to building web applications using it. We will call applications built in this style _Hypermedia-Driven Applications_ , or HDAs, and we contrast them with a popular style in use today, the Single Page Application.
#
# A Hypermedia-Driven Application is an application built on top of a hypermedia system that respects and utilizes the hypermedia functionality of that underlying system.

# %% [markdown]
# ## Goals
#
# The goal of this book is to give you a strong sense of how the RESTful, hypermedia system architecture _differs_ from other client-server systems, and what the strengths (and weaknesses) of the hypermedia approach are. Further, we hope to convince you that the hypermedia architecture is _relevant_ to developers building modern web applications.
#
# We aim to give you the tools to evaluate the requirements for an application and answer the question:
#
# “Could I build this as a Hypermedia-Driven Application?”
#
# We hope that for many applications the answer to that question will be “Yes!”

# %% [markdown]
# ## Book Layout
#
# The book is broken into three parts:
#
#   * An introduction (or re-introduction) to hypermedia, with a particular focus on HTML and HTTP. We will finish this review of core hypermedia concepts by creating a simple “Web 1.0“-style application, Contact.app, for managing contacts.
#
#   * Next we will look at how we can use [htmx](https://htmx.org), a hypermedia-oriented JavaScript library created by the authors of this book, to improve Contact.app. By using htmx, we will be able to achieve a level of interactivity in our application that many developers would expect to require a large, sophisticated front end library, such as React. Thanks to htmx, we will be able to do this using hypermedia as our system architecture.
#
#   * Finally, we will look at a completely different hypermedia system, Hyperview. Hyperview is a _mobile_ hypermedia system, related to, but distinct from the web and created by one of the authors of this book – Adam Stepinski. It supports _mobile specific_ features by providing not only a mobile specific hypermedia, but also a mobile hypermedia client. These novel components, combined with any HTTP server, make it possible to build mobile Hypermedia-Driven Applications.
#
#
#
#
# Note that each section is _somewhat_ independent of the others. If you already know hypermedia in-depth and how basic Web 1.0 applications function, you may want to skip ahead to the second section on htmx and how to build modern web applications using hypermedia. Similarly, if you are well versed in htmx and want to dive into a novel _mobile_ hypermedia, you can skip ahead to the Hyperview section.
#
# That being said, the book is designed to be read in order and both the htmx and Hyperview sections build on the Web 1.0 application described at the end of the first section. Furthermore, even if you _are_ well versed in all the concepts of hypermedia and details of HTML & HTTP, it is likely worth it to at least skim through the first few chapters for a refresher.

# %% [markdown]
# ## Hypermedia: A New Generation
#
# Hypermedia isn’t a frequent topic of discussion these days. Even many older programmers who grew up with the web in the late 1990s and early 2000s haven’t thought much about these ideas in years. Many younger web developers have grown up knowing nothing but Single Page Applications and the frameworks that are used to build them.
#
# In particular, many young web developers began their careers by building React.js applications that interact with a Node server using a JSON API; they may never have learned about hypermedia as a system at all.
#
# This is a tragedy, and, frankly, a failure on the part of the thought leaders in the web development community to properly communicate and advocate for the hypermedia approach.
#
# Hypermedia was a great idea! It still is!
#
# By the end of this book, you will have the tools and the _language_ to put this great idea to work in your own applications. And, further, you will be able to bring the ideas and concepts of hypermedia systems to the broader web development community.
#
# Hypermedia can compete, hypermedia _can win_ , hypermedia _has won_ as an architectural choice against the Single Page Application approach, but _only_ if smart people (like you) learn about it, build with it and then tell the world about it.
#
# > Remember the message? “The future is not set. There is no fate but what we make for ourselves.”
#
#  Kyle Reese, Terminator 2: Judgement Day

# %% [markdown]
# ## HTML Notes: Hypermedia In Practice
#
# Clearly, HTML plays a central role in the story we tell here. At the end of each chapter we will share what we have learned about writing HTML for hypermedia-driven web applications.
#
# To start, remember that our web applications are not islands. We’re writing HTML not just for a particular application, but also to play along with other members of the web. When we write with the hypermedia _system_ in mind, we’re better able to tap the range of abilities available to the web.
#
# HTML is hypermedia-friendly when it is written for the full range of constituents of the hypermedia system. It conveys the state of an application to people viewing our sites with a browser, as well as to people listening to screen readers that read sites aloud. It conveys the aims of our sites to search engines that scrape sites programmatically. It also conveys its behavior as clearly as possible to other developers.
#
# No, we can’t fix every problem with good HTML. The mantra that HTML is “accessible by default” is misleading. We would miss out on important opportunities if we shunned other technologies like JavaScript. And we still need to test, a lot, everywhere, to ensure things work as expected.
#
# But good HTML lets browsers do a _lot_ of work for us.
#
# [Previous: Hypermedia Concepts](/part/hypermedia-concepts/)
#
# [Next: Hypermedia: A Reintroduction](/hypermedia-a-reintroduction/)
#
# [Hypermedia Systems](/) [Contents](/book/contents/)

# %% [markdown]
# Looks like the latest is charting out what is to come. Not much new stuff to really dig into, do you agree? If so, lets summarize this page for a future you akin to what we did in the beginning. Thanks
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# You're right — this section is mostly roadmap and motivation rather than new concepts. Let's summarize!
#
# ---
#
# **Chapter Covered**: Introduction from "Hypermedia Systems"
#
# **Key Points**:
#
# 1. **Hypermedia-Driven Applications (HDAs)**: Applications built on a hypermedia system that actually *use* its hypermedia capabilities — contrasted with SPAs which largely bypass them.
#
# 2. **REST Clarification**: Fielding's REST described the 1990s web — browsers exchanging HTML with links and forms. The modern use of "REST" for JSON APIs is a misapplication of the term, since JSON lacks hypermedia controls.
#
# 3. **Book Structure**:
#    - Part 1: Hypermedia fundamentals (HTML, HTTP), build a "Web 1.0" Contact.app
#    - Part 2: Enhance it with **htmx** — a hypermedia-oriented JS library that adds interactivity while staying hypermedia-driven
#    - Part 3: **Hyperview** — a mobile hypermedia system (different from web, but same principles)
#
# 4. **Book's Goal**: Help you answer "Could I build this as a Hypermedia-Driven Application?" — and often the answer is yes.
#
# 5. **HTML Note**: Good HTML works *with* the hypermedia system — it serves browsers, screen readers, search engines, and other developers. "Good HTML lets browsers do a lot of work for us."
#
# ---
#
# Does that capture what you'd want a future-you to remember? Want to add or change anything?

# %% [markdown]
# By "future you" I meant the language model
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Ah, got it! Yes, the summary I wrote is intended for that purpose — so a future instance of me can quickly understand where you left off and what concepts you've covered.
#
# Looking back at the earlier summary in your notes, I should format it similarly. Here's a revised version:
#
# ---
#
# **Learner Context**: New to web programming, comfortable with Python, prefers learning through discussion and exploring concepts.
#
# **Chapter Covered**: Introduction from "Hypermedia Systems"
#
# **Key Concepts Discussed**:
#
# 1. **REST Misuse Clarified**: Fielding's REST described the 1990s web (browsers exchanging HTML). Modern "REST" for JSON APIs misapplies the term — JSON lacks hypermedia controls. Current JSON APIs may be *stateless* (one REST principle) but aren't *hypermedia-driven* (the core principle).
#
# 2. **Hypermedia-Driven Applications (HDAs)**: Apps that actually use the hypermedia capabilities of the underlying system, contrasted with SPAs which bypass them.
#
# 3. **Book Roadmap**:
#    - Part 1: HTML, HTTP fundamentals → build "Web 1.0" Contact.app
#    - Part 2: Enhance with **htmx** (hypermedia-oriented JS library)
#    - Part 3: **Hyperview** (mobile hypermedia system)
#
# 4. **HTML Note**: Good HTML serves the whole hypermedia system — browsers, screen readers, search engines, developers. Let browsers do the work.
#
# ---
#
# Ready for the next chapter: *Hypermedia: A Reintroduction*
#
# ---
#
# Want me to add this as a note to your dialog?

# %% [markdown]
# Yes please
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
#
#
# <details class='tool-usage-details'>
#
# ```json
# {
#   "id": "toolu_01KV9f6pXuw4SmVu9XevYpuN",
#   "call": {
#     "function": "add_msg",
#     "arguments": {
#       "msg_type": "note",
#       "content": "\ud83e\udde0\ud83e\udde0\ud83e\udde0\ud83e\udde0\ud83e\udde0\ud83e\udde0\ud83e\udde0\ud83e\udde0\ud83e\udde0\ud83e\udde0\ud83e\udde0\ud83e\udde0\ud83e\udde0\ud83e\udde0\ud83e\udde0\ud83e\udde0\ud83e\udde0\ud83e\udde0\ud83e\udde0\n\n**Learner Context**: New to web programming, comfortable with Python, prefers l<TRUNCATED>",
#       "placement": "at_end"
#     }
#   },
#   "result": "'_b6950cc5'"
# }
# ```
#
# </details>
#
# Done! I've added the summary note at the end. It will help me (or any future instance) quickly understand your learning journey when you come back. Happy reading! 📚

# %% [markdown]
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# **Learner Context**: New to web programming, comfortable with Python, prefers learning through discussion and exploring concepts.
#
# **Chapter Covered**: Introduction from "Hypermedia Systems"
#
# **Key Concepts Discussed**:
#
# 1. **REST Misuse Clarified**: Fielding's REST described the 1990s web (browsers exchanging HTML). Modern "REST" for JSON APIs misapplies the term — JSON lacks hypermedia controls. Current JSON APIs may be *stateless* (one REST principle) but aren't *hypermedia-driven* (the core principle - HATEOAS: Hypermedia As The Engine Of Application State).
#
# 2. **Hypermedia-Driven Applications (HDAs)**: Apps that actually use the hypermedia capabilities of the underlying system, contrasted with SPAs which bypass them.
#
# 3. **Book Roadmap**:
#    - Part 1: HTML, HTTP fundamentals → build "Web 1.0" Contact.app
#    - Part 2: Enhance with **htmx** (hypermedia-oriented JS library)
#    - Part 3: **Hyperview** (mobile hypermedia system)
#
# 4. **HTML Note**: Good HTML serves the whole hypermedia system — browsers, screen readers, search engines, developers. Let browsers do the work.
#
# ---
#
# Ready for the next chapter: *Hypermedia: A Reintroduction*
