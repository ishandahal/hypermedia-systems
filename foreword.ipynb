# %%
from dialoghelper import *

# %%
tool_info()

# %% [markdown]
# Tools available from `dialoghelper`:
#
# - &`curr_dialog`: Get the current dialog info.
# - &`msg_idx`: Get absolute index of message in dialog.
# - &`add_html`: Send HTML to the browser to be swapped into the DOM using hx-swap-oob.
# - &`find_msg_id`: Get the current message id.
# - &`find_msgs`: Find messages in current specific dialog that contain the given information.
#   - (solveit can often get this id directly from its context, and will not need to use this if the required information is already available to it.)
# - &`read_msg`: Get the message indexed in the current dialog.
#   - To get the exact message use `n=0` and `relative=True` together with `msgid`.
#   - To get a relative message use `n` (relative position index).
#   - To get the nth message use `n` with `relative=False`, e.g `n=0` first message, `n=-1` last message.
# - &`del_msg`: Delete a message from the dialog.
# - &`add_msg`: Add/update a message to the queue to show after code execution completes.
# - &`update_msg`: Update an existing message.
# - &`url2note`: Read URL as markdown, and add a note below current message with the result
# - &`msg_insert_line`: Insert text at a specific location in a message.
# - &`msg_str_replace`: Find and replace text in a message.
# - &`msg_strs_replace`: Find and replace multiple strings in a message.
# - &`msg_replace_lines`: Replace a range of lines in a message with new content.
#   - Always first use `read_msg( msgid=msgid, n=0, relative=True, nums=True)` to view the content with line numbers.

# %%
foreword_url = "https://hypermedia.systems/foreword/"
foreword = url2note(foreword_url)

# %% [markdown]
# [Previous: Dedication](/dedication/)
#
# [Next: Hypermedia Concepts](/part/hypermedia-concepts/)

# %% [markdown]
# # Foreword
#
# Contents
#
# Foreword
#
# While there have been many books on the topic of hypermedia, there is a select number of publications that chronicle important advances in the field of hypermedia and this book is one of them. Not only does this book describe the benefits of creating hypermedia-driven applications (HDAs), it leads the reader through working and practical examples of how to do just that. And, in doing so, the authors (Gross, Stepinski, and Akşimşek) call out contributions from important figures in the history of hypermedia systems. And, as of this writing, that history spans more than half a century.
#
# In 1974, Ted Nelson’s _“Computer Lib/Machine Dreams”_ marked the start of the modern hypermedia era with a book that Steven Levy (author of _“Hackers”_) described as “the epic of the computer revolution.” Nelson is credited with coining the terms HyperText, HyperLink, HyperMedia, and HyperData as well as Intertwingularity; the notion that all information is connected — both intertwined and intermingled. Almost half a century ago, he foretold a future where any person could publish anything anytime without the need for permission from any central controlling source. And his hyperlinks were the engine of that future.
#
# It took two decades before Nelson’s idea of intertwingled computing became widespread. Along the way, Douglas Engelbart created the _oN-Line System_ or NLS, Wendy Hall built the _Microcosm_ , and, eventually, in the 1980s, Tim Berners-Lee defined the World Wide Web (WWW), HTML, and HTTP. It was Berners-Lee’s iteration that has become the backbone and the standard for the intertwingularity we all experience today.
#
# By the year 2000, the technical foundations of “the web” were documented in Roy Fielding’s PhD dissertation _“Architectural Styles and the Design of Network-based Software Architectures”_). In that work, Fielding defined the architectural model of _REpresentational State Transfer_ or REST. This set of system properties and implementation constraints have proven — even a quarter-century later — to be a reliable model for designing and building the intertwingled machines that today affect billions of people around the globe.
#
# Even though Fielding’s work was important, it wasn’t until Leonard Richardson and Sam Ruby published _“RESTful Web Services”_ in 2008 that the REST model became well-known to the world of software architecture and development. Backed by the Ruby programming platform, the ideas behind Fielding’s REST model became _de rigueur_ for the creation of web-based services and client applications.
#
# One of the reasons Richardson and Ruby’s work was so important was that, unlike dissertations and futuristic predictions, the _RESTful Web Services_ book outlined a practical working framework for building powerful applications for the Web. It described not only the power of REST but also provided step-by-step instructions on how to build them. Richardson and Ruby brought together the hypermedia scholarship of the previous twenty years all in one place.
#
# And now we can add this book (_“Hypermedia Systems”_) to that list of important works. From the book’s introduction through the step-by-step directions on how to use HTMX for browsers and Hyperview for mobile devices, the authors describe the benefits of creating hypermedia-driven applications (HDAs). They also offer dozens of practical working examples the reader can use right away in building their own hypermedia solutions.
#
# I’ve been working in the field of hypermedia for close to thirty years and have seen quite a few books, papers, dissertations, and programming platforms come and go in that time. Occasionally, one of these works “nails it” — provides the right mix of theory and practice delivered in a way that helps readers make a connection between their own efforts and the activities of the community at large. I am happy to say that this book is one of those works. The authors have not only created powerful tooling in HTMX and Hyperview, they have also advanced the notion of hypermedia systems and hypermedia-driven applications in ways that a wide audience can understand and apply.
#
# Nelson describes a future where the barriers to publishing and data sharing are lowered and the creative energies of the world are easily shared and applied. This is neither a new or unique idea but one that does need continual renewal and encouragement. Nelson saw his hyperlink and hypermedia as the driving force for intertwingularity between people and machines around the world. In this idea alone, hypermedia is a powerful approach to creating computer systems that enable people to work together for the common good. As this book’s authors say, “Hypermedia was a great idea! It still is!”
#
# _Mike Amundsen, April 2023_
#
# [Previous: Dedication](/dedication/)
#
# [Next: Hypermedia Concepts](/part/hypermedia-concepts/)
#
# [Hypermedia Systems](/) [Contents](/book/contents/)

# %% [markdown]
# I have a bunch of pargraphs. How can I convert them into individual note so that I can use ask clarifications to you for each as i read them?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Great question! There are a couple of approaches:
#
# 1. **Manual approach**: Copy each paragraph into a new note one at a time (tedious but simple)
# 2. **Code approach**: Write a short script to split the text and create multiple notes automatically using `add_msg`
#
# For the code approach, you'd basically:
# - Get the content from the existing note
# - Split it into paragraphs
# - Loop through and call `add_msg` for each one
#
# Would you like to try writing the code yourself, or would you prefer I write it for you? Also, how comfortable are you with Python?

# %% [markdown]
# I am confortable with using python. Though I would not consider myself an expert. I would prefer doing it with code. Can I read the note with code as well or should I copy the contents manually?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Yes, you can read the note with code! The `read_msg` function lets you get the content of any message.
#
# Looking at your context, the foreword content is in the note with id `_962498a5`. You can read it like this:
#
# ```python
# read_msg(msgid="_962498a5", n=0, relative=True)
# ```
#
# Try running that first and see what you get back. Once you have the content, you can think about how to split it into paragraphs. What do you think you might use to split text into paragraphs?

# %%
read_msg(msgid="_962498a5", n=0, relative=True)

# %%
paragraphs = msg["msg"]["content"].split("\n\n")
for para in paragraphs:
    add_msg(para)

# %% [markdown]
# # Foreword

# %% [markdown]
# While there have been many books on the topic of hypermedia, there is a select number of publications that chronicle important advances in the field of hypermedia and this book is one of them. Not only does this book describe the benefits of creating hypermedia-driven applications (HDAs), it leads the reader through working and practical examples of how to do just that. And, in doing so, the authors (Gross, Stepinski, and Akşimşek) call out contributions from important figures in the history of hypermedia systems. And, as of this writing, that history spans more than half a century.

# %% [markdown]
# In 1974, Ted Nelson’s _“Computer Lib/Machine Dreams”_ marked the start of the modern hypermedia era with a book that Steven Levy (author of _“Hackers”_) described as “the epic of the computer revolution.” Nelson is credited with coining the terms HyperText, HyperLink, HyperMedia, and HyperData as well as Intertwingularity; the notion that all information is connected — both intertwined and intermingled. Almost half a century ago, he foretold a future where any person could publish anything anytime without the need for permission from any central controlling source. And his hyperlinks were the engine of that future.

# %% [markdown]
# It took two decades before Nelson’s idea of intertwingled computing became widespread. Along the way, Douglas Engelbart created the _oN-Line System_ or NLS, Wendy Hall built the _Microcosm_ , and, eventually, in the 1980s, Tim Berners-Lee defined the World Wide Web (WWW), HTML, and HTTP. It was Berners-Lee’s iteration that has become the backbone and the standard for the intertwingularity we all experience today.

# %% [markdown]
# By the year 2000, the technical foundations of “the web” were documented in Roy Fielding’s PhD dissertation _“Architectural Styles and the Design of Network-based Software Architectures”_). In that work, Fielding defined the architectural model of _REpresentational State Transfer_ or REST. This set of system properties and implementation constraints have proven — even a quarter-century later — to be a reliable model for designing and building the intertwingled machines that today affect billions of people around the globe.

# %% [markdown]
# Even though Fielding’s work was important, it wasn’t until Leonard Richardson and Sam Ruby published _“RESTful Web Services”_ in 2008 that the REST model became well-known to the world of software architecture and development. Backed by the Ruby programming platform, the ideas behind Fielding’s REST model became _de rigueur_ for the creation of web-based services and client applications.

# %% [markdown]
# One of the reasons Richardson and Ruby’s work was so important was that, unlike dissertations and futuristic predictions, the _RESTful Web Services_ book outlined a practical working framework for building powerful applications for the Web. It described not only the power of REST but also provided step-by-step instructions on how to build them. Richardson and Ruby brought together the hypermedia scholarship of the previous twenty years all in one place.

# %% [markdown]
# And now we can add this book (_“Hypermedia Systems”_) to that list of important works. From the book’s introduction through the step-by-step directions on how to use HTMX for browsers and Hyperview for mobile devices, the authors describe the benefits of creating hypermedia-driven applications (HDAs). They also offer dozens of practical working examples the reader can use right away in building their own hypermedia solutions.

# %% [markdown]
# I’ve been working in the field of hypermedia for close to thirty years and have seen quite a few books, papers, dissertations, and programming platforms come and go in that time. Occasionally, one of these works “nails it” — provides the right mix of theory and practice delivered in a way that helps readers make a connection between their own efforts and the activities of the community at large. I am happy to say that this book is one of those works. The authors have not only created powerful tooling in HTMX and Hyperview, they have also advanced the notion of hypermedia systems and hypermedia-driven applications in ways that a wide audience can understand and apply.

# %% [markdown]
# Nelson describes a future where the barriers to publishing and data sharing are lowered and the creative energies of the world are easily shared and applied. This is neither a new or unique idea but one that does need continual renewal and encouragement. Nelson saw his hyperlink and hypermedia as the driving force for intertwingularity between people and machines around the world. In this idea alone, hypermedia is a powerful approach to creating computer systems that enable people to work together for the common good. As this book’s authors say, “Hypermedia was a great idea! It still is!”

# %% [markdown]
# I am new to web probramming. Can you tell me in a bit more detail what the foreword is talking about above
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Sure! The foreword is essentially telling the story of how the web came to be and why this book matters. Let me give you a quick overview of the main ideas:
#
# **The big picture**: The foreword traces the history of "hypermedia" — which is basically the idea that information can be connected through links (like when you click a link on a webpage to go somewhere else).
#
# **Key people mentioned**:
# - **Ted Nelson** (1974) — coined terms like "hypertext" and "hyperlink" and imagined a connected world
# - **Tim Berners-Lee** (1980s) — created the World Wide Web, HTML, and HTTP (the stuff that actually powers websites today)
# - **Roy Fielding** (2000) — defined REST, which is a way of designing web systems
#
# **What the book is about**: It teaches you how to build "hypermedia-driven applications" (HDAs) using tools called HTMX (for browsers) and Hyperview (for mobile).
#
# Is there a specific concept you'd like me to explain more? For instance:
# - What exactly is "hypermedia" vs regular media?
# - What is REST and why does it matter?
# - What's the difference between how websites were built then vs now?
#
# Which of these interests you most, or is there something else from the foreword you'd like clarified?

# %% [markdown]
# All this is new to me. Can we look at each of those questions one by one
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Absolutely! Let's start with the first one:
#
# **What is "hypermedia" vs regular media?**
#
# Think about a printed book or a photo. You can read it or look at it, but it just sits there — it doesn't *do* anything. That's regular media.
#
# Now think about a webpage. You can click on things! A link takes you somewhere else. A button might load new content. An image might be clickable. The content is *connected* to other content and can *respond* to your actions.
#
# That's the "hyper" part — it means the media (text, images, etc.) has links and interactivity built in.
#
# A simple example:
# - **Regular text**: "For more info, see page 42"
# - **Hypertext**: "For more info, [click here](#)" ← and clicking actually takes you there
#
# Does that make sense? Any questions about this before we move on to REST?

# %% [markdown]
# That makese sense. Media that is linked like it wasn't before. We can continue
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠
#
# Great! Let's move on to:
#
# **What is REST and why does it matter?**
#
# REST stands for *REpresentational State Transfer*. It's a set of guidelines for how computers should talk to each other over the web.
#
# Here's a simple way to think about it: Imagine you're at a restaurant.
#
# 1. You (the client) look at a **menu** (a representation of what's available)
# 2. You **request** something: "I'd like the pasta"
# 3. The kitchen (the server) **responds** by giving you the pasta
#
# REST works similarly:
# - Your browser (client) requests a webpage
# - The server sends back a *representation* of that page (HTML, images, etc.)
# - Each request is independent — the server doesn't need to remember your previous requests
#
# The key insight is that the server sends you *data plus links* telling you what you can do next. Just like a menu tells you what you can order, a webpage tells you what you can click.
#
# Before REST, there wasn't a consistent way to think about this — everyone did it differently. Fielding's ideas gave developers a shared language and approach.
#
# Does this restaurant analogy help? Any questions before we look at how websites were built then vs now?

# %% [markdown]
# Could you expand the analogy and include one for not using REST?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Sure! Let's compare two restaurants:
#
# **Restaurant WITHOUT REST** (the old way):
#
# - You walk in and the waiter remembers everything about you from last time
# - There's no menu — you have to ask "what can I do?" and the waiter tells you verbally
# - The waiter says "You usually get pasta, want that again?"
# - If a *different* waiter serves you, they're confused — they don't know your history
# - If you bring a friend, they have to learn a completely different system to order
#
# This is "stateful" — the server has to keep track of who you are and what you've done. It's fragile and doesn't scale well.
#
# **Restaurant WITH REST**:
#
# - Every table gets a fresh menu (the current state of what's available)
# - The menu shows everything you can do: appetizers, mains, desserts, with prices
# - You make a request, you get a response — done
# - Any waiter can serve you because all the info is in the menu and your order
# - Your friend uses the exact same menu and system
#
# This is "stateless" — each interaction is self-contained. The menu (the hypermedia) tells you everything you need to know about what actions are possible.
#
# The big win: REST systems are simpler, more reliable, and can handle millions of "customers" because the server isn't trying to remember everyone's history.
#
# Does that help clarify the difference?

# %% [markdown]
# It does. We can move on
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠
#
# Great! Now for the third question:
#
# **How were websites built then vs now?**
#
# In the early web (1990s-2000s), it worked just like our REST restaurant:
#
# - You click a link → browser requests a new page → server sends back a *whole new HTML page*
# - Every action meant loading a completely fresh page
# - The HTML itself contained the links telling you what you could do next
#
# This is the "hypermedia" approach — simple and robust.
#
# **Then things changed** (2010s onwards):
#
# Developers started building "Single Page Applications" (SPAs):
# - The browser loads one page, then uses JavaScript to fetch *just data* (often as JSON)
# - JavaScript rebuilds parts of the page without full reloads
# - Feels faster and more "app-like"
#
# **The problem?**
# - The browser no longer receives hypermedia (HTML with links) — just raw data
# - The JavaScript has to "know" what links and actions are possible — it's hardcoded
# - More complex, more things can break, harder to maintain
#
# **What this book argues**:
# The original hypermedia approach was actually great! Tools like HTMX let you get the "app-like" feel (partial page updates) while *still* using hypermedia — best of both worlds.
#
# Does this make sense? Any questions about this shift, or are you ready to dive into the actual book content?

# %% [markdown]
# Can you tell me more about the SPAs. Why was it introduced and is it not used any more? Or is the book's intent to show that SPAs are not that good?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Great questions! Let me break this down:
#
# **Why were SPAs introduced?**
#
# In the early 2010s, developers wanted web apps to feel more like desktop or mobile apps:
# - No "flash" of a blank screen between pages
# - Faster-feeling interactions
# - Richer, more dynamic user interfaces (think Gmail, Google Maps, Facebook)
#
# SPAs solved this by keeping one page loaded and updating parts of it dynamically with JavaScript.
#
# **Are SPAs still used?**
#
# Absolutely! SPAs are *very* popular today. Frameworks like React, Vue, and Angular are widely used and are all SPA-oriented. Many of the apps you use daily are probably SPAs.
#
# **So what's the book's point?**
#
# The book isn't saying SPAs are "bad" — they're saying:
#
# 1. SPAs added a lot of complexity that isn't always necessary
# 2. Many apps don't *need* to be SPAs but were built that way because it became the default
# 3. You can get many of the benefits (smooth partial updates) while keeping the simplicity of hypermedia
#
# It's more "here's a simpler alternative you might not have considered" rather than "SPAs are wrong."
#
# Does that help clarify? Would you like to know more about *when* an SPA makes sense vs when hypermedia might be a better fit?

# %% [markdown]
# Yes
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Perfect! Let's think about when each approach shines:
#
# **SPAs make sense when**:
# - You need very rich, interactive UI (like a photo editor, drawing app, or complex dashboard)
# - You're building something that feels like a "desktop app in the browser"
# - You need to work offline or with minimal server communication
# - Example: Figma (design tool), Google Docs
#
# **Hypermedia makes sense when**:
# - You're building content-driven sites (blogs, e-commerce, forums)
# - Most interactions are "click something, see new content"
# - You want simpler code that's easier to maintain
# - You want better accessibility and SEO by default
# - Example: Amazon, Wikipedia, most business websites
#
# **The interesting middle ground** (what HTMX offers):
# - Start with hypermedia (simple, server sends HTML)
# - Add SPA-like smoothness only where needed (update just part of the page)
# - Keep it simple but still feel modern
#
# Think about a website you use often. What kind of interactions does it have? Does it feel more like an "app" or more like clicking through pages?

# %% [markdown]
# Can hypermedia be used to completely replace SPAs with similar feel?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# That's the key question! The honest answer is: *mostly, but not always*.
#
# **What hypermedia + HTMX can match**:
# - Smooth partial page updates (no full page reloads)
# - Form submissions without page flicker
# - Loading indicators, transitions
# - Most typical web interactions (search, filters, pagination, modals)
#
# This covers probably 80-90% of what most websites actually need.
#
# **Where SPAs still have an edge**:
# - Very complex client-side state (like a multi-step wizard with lots of interdependencies)
# - Real-time collaborative editing (Google Docs-style)
# - Heavy offline support
# - Highly interactive graphics/games
# - When you need to minimize server round-trips (every HTMX action calls the server)
#
# **The practical reality**:
# Many teams built SPAs for apps that didn't really need them — because that's what was trendy. They ended up with more complexity than necessary.
#
# The book's argument is: start with hypermedia. If you hit a wall where you genuinely need SPA-style JavaScript, add it for *just that part*. Don't default to the complex solution.
#
# Have you ever used a website that felt overly slow or complex for what it was doing? Or conversely, one that felt surprisingly smooth and simple?

# %% [markdown]
# _Mike Amundsen, April 2023_

# %% [markdown]
# [Previous: Dedication](/dedication/)

# %% [markdown]
# [Next: Hypermedia Concepts](/part/hypermedia-concepts/)

# %% [markdown]
# [Hypermedia Systems](/) [Contents](/book/contents/)

# %% [markdown]
# Please summarize this dialogue for a future you so that you have all the context from this chapter to move on to the next.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Here's a summary for continuing the learning journey:
#
# ---
#
# **Learner Context**: New to web programming, comfortable with Python (not expert level), prefers learning through code and interactive exploration.
#
# **Chapter Covered**: Foreword of "Hypermedia Systems" by Gross, Stepinski, and Akşimşek
#
# **Key Concepts Discussed**:
#
# 1. **Hypermedia vs Regular Media**: Regular media is static (books, photos). Hypermedia is linked and interactive — content that connects to other content and responds to actions (clickable links, buttons).
#
# 2. **REST (REpresentational State Transfer)**: Guidelines for how computers talk over the web. Used restaurant analogy:
#    - *Without REST*: Waiter remembers your history, no menu, fragile, doesn't scale
#    - *With REST*: Fresh menu each visit, stateless, any waiter can serve you, self-contained interactions
#
# 3. **Evolution of Web Development**:
#    - Early web: Click → full page reload → server sends complete HTML with links (hypermedia approach)
#    - SPAs (2010s+): Single page loads, JavaScript fetches JSON data, rebuilds page parts — faster feel but more complex
#
# 4. **SPAs vs Hypermedia**:
#    - SPAs: Good for rich interactive apps (Figma, Google Docs), offline support, complex state
#    - Hypermedia: Good for content-driven sites, simpler code, easier maintenance
#    - HTMX: Middle ground — hypermedia with SPA-like smoothness where needed
#
# 5. **Book's Thesis**: Hypermedia was a great idea that got overlooked. Most apps don't need SPA complexity. Start simple, add complexity only when needed.
#
# ---
#
# Ready for the next chapter: *Hypermedia Concepts*
